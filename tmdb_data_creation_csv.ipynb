# %%
import requests
import pandas as pd

# %%
requests.get('https://api.themoviedb.org/3/movie/popular?api_key=0d600a032c9018468cffbc9bc7b17b95&language=en-US&page=10')
# Out:
# <Response [200]>

# %%
response=requests.get('https://api.themoviedb.org/3/movie/popular?api_key=0d600a032c9018468cffbc9bc7b17b95&language=en-US&page=1').json()

# %%
d={'name':['Rahul','Rohit'],'Age':[34,56]}

df=pd.DataFrame(d)

df
# Out:
#     name  Age
# 0  Rahul   34
# 1  Rohit   56

# %%
popularity=[]
vote_count=[]
title=[]
vote_avg=[]
original_lang=[]
overview=[]
release_date=[]


for i in response['results']:
    popularity.append(i['popularity'])
    vote_count.append(i['vote_count'])
    title.append(i['title'])
    vote_avg.append(i['vote_average'])
    original_lang.append(i['original_language'])
    overview.append(i['overview'])
    release_date.append(i['release_date'])
    
d={'title':title, 'overview':overview, 'original_lang':original_lang,'release_date':release_date,'vote_avg':vote_avg,'vote_count':vote_count,'popularity':popularity}
    
df=pd.DataFrame(d)

df
    #print(i['title'],i['vote_average'])
# Out:
#                                                 title  \
# 0                        Puss in Boots: The Last Wish
# 1                                               M3GAN
# 2                            Avatar: The Way of Water
# 3                                            Devotion
# 4                                        The Enforcer
# 5                                       Violent Night
# 6                                               Troll
# 7                       Encanto at the Hollywood Bowl
# 8                                          Black Adam
# 9                   Glass Onion: A Knives Out Mystery
# 10                                             Avatar
# 11                     Black Panther: Wakanda Forever
# 12                                     The Woman King
# 13                   Roald Dahl's Matilda the Musical
# 14                                    The Last Client
# 15  The Chronicles of Narnia: The Lion, the Witch ...
# ...

# %%
final=pd.DataFrame()

for j in range(1,15):
    
    response=requests.get('https://api.themoviedb.org/3/movie/popular?api_key=0d600a032c9018468cffbc9bc7b17b95&language=en-US&page={}'.format(j)).json()
    
    popularity=[]
    vote_count=[]
    title=[]
    vote_avg=[]
    original_lang=[]
    overview=[]
    release_date=[]


    for i in response['results']:
        popularity.append(i['popularity'])
        vote_count.append(i['vote_count'])
        title.append(i['title'])
        vote_avg.append(i['vote_average'])
        original_lang.append(i['original_language'])
        overview.append(i['overview'])
        release_date.append(i['release_date'])

    d={'title':title, 'overview':overview, 'original_lang':original_lang,'release_date':release_date,'vote_avg':vote_avg,'vote_count':vote_count,'popularity':popularity}

    df=pd.DataFrame(d)
   
    final=final.append(df,ignore_index=True)
# Out:
# C:\Users\nishant\AppData\Local\Temp\ipykernel_8808\4112925519.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df,ignore_index=True)

# %%
final
# Out:
#                             title  \
# 0    Puss in Boots: The Last Wish
# 1                           M3GAN
# 2        Avatar: The Way of Water
# 3                        Devotion
# 4                    The Enforcer
# ..                            ...
# 275             The Suicide Squad
# 276                      Bromates
# 277      Clifford the Big Red Dog
# 278          John Wick: Chapter 2
# 279                       Ice Age
#
#                                               overview original_lang  \
# 0    Puss in Boots discovers that his passion for a...            en
# 1    A brilliant toy company roboticist uses artifi...            en
# 2    Set more than a decade after the events of the...            en
# 3    The harrowing true story of two elite US Navy ...            en
# 4    A noir thriller set in Miami, the film follows...            en
# ..                                                 ...           ...
# ...

# %%
final.to_csv('movies.csv')
